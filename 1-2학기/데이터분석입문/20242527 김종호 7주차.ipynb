# %%
pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ------------- ------------------------ 20.5/59.7 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------- 59.7/59.7 kB 798.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB 59.5 kB/s eta 0:03:31
#    ---------------------------------------- 0.1/12.6 MB 276.8 kB/s eta 0:00:45
#    - -------------------------------------- 0.5/12.6 MB 1.1 MB/s eta 0:00:12
# ...

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/167.0 kB ? eta -:--:--
#      --------------------------- ---------- 122.9/167.0 kB 7.0 MB/s eta 0:00:01
#      -------------------------------------- 167.0/167.0 kB 5.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---- ----------------------------------- 0.9/7.8 MB 19.4 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/7.8 MB 22.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/7.8 MB 22.5 MB/s eta 0:00:01
#    ------ --------------------------------- 1.3/7.8 MB 7.8 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/7.8 MB 11.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/7.8 MB 11.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/7.8 MB 11.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/7.8 MB 11.1 MB/s eta 0:00:01
# ...

# %%
import numpy as np
import matplotlib as mpl

print(np._version_)
print(mpl._version_)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 2
#       1 import numpy as np
# ----> 2 import matplotlib as mpl
#       4 print(np._version_)
#       5 print(mpl._version_)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt 

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 plt.rc('font', family='Malgun Gothic')
#       4 plt.rc('axes', unicode_minus=False)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import matplotlib.pyplot as plt

plt.plot([10,5,25,30,20])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 plt.plot([10,5,25,30,20])
#       4 plt.show()
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
plt.plot([1,3,5,7,9],[8,6,17,22,3])
plt.title('직선 그래프 그리기')
plt.show()
# Out:
#   Cell In[17], line 4
#     plt.
#         ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[2,3,5,7,11]

plt.plot(x,y,marker='o', linestyle='-',color='b',label='소수(prime Numbers)' )

plt.xlabel('x-축(axis)')
plt.ylabel('y-축(axis)')
plt.title('소수 그리기(prime Numbers plot)')

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[10,20,30,40], color='r', linestyle='--',marker='d', linewidth=3, label='thick line')

plt.plot([1,2,3,4],[40,30,20,10],'b',ls=':', marker='^',lw=0.5,label='thin line')

plt.title('속성 markwe linewidth linestyle')
plt.xlabel('x 축(axis)')
plt.ylabel('y 축(axis)')
plt.legend()
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt
np.random.seed(2025)

N=80
x= np.random.rand(N)
y= np.random.rand(N)
colors = np.random.rand(N)
area = (20* np.random.rand(N)) **2

plt.scatter(x,y,s=area,c=colors,alpha=0.7)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.randint(-100,100,1000)
y=np.random.randint(-10,100,1000)
mask1 =abs(x) > 50
mask2 =abs(y) > 50
x=x[mask1 +mask2]
y=y[mask1 +mask2]

plt.scatter(x,y,c=x,xmap='jet', alpht=0.4)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.bar(["Res", "Green","Blue"], [8,5,10])
plt.show()

# %%
import matplotlib.pyplot as plt

x=["red","green","blue"]
plt.bar(c, [10,4,12], color=c, alpht=.4)

# %%
import matplotlib.pyplot as plt

plt.figure(figure=(6,4))

plt.hist([1,1,1,2,2,3,4,5,6,6,6,6], rwidth=.98, bins=[.5,1.5,plt.xticks(range(1,7))])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
sice = np.random.choice(range(1,7), 1000000, p=[0.15,0.25,0.3,0.1,0.1,0.1])

plt.figure(figsize=(5,3), dpi=200)

plt.hist(dice, rwidth=.98, bins=np.arange(.5,7))
plt.xticks(range(1,7))

plt.savefig('주사위.png')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9,4))

plt.subplot(2,3,1)
plt.subplot(2,3,5)
plt.subplot(2,3,6)

plt.plot()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9,4))

plt.subplots(2,4)
plt.show()

# %%
import matplotlib.pyplot as plt 

fig = plt.figure()

fig.add_subplot(321).set_title('321')
fig.add_subplot(321).set_title('322')
fig.add_subplot(321).set_title('323')
fig.add_subplot(321).set_title('324')
fig.add_subplot(321).set_title('325')
fig.add_subplot(321).set_title('326')

fig.subplots_adjust(wspace=.2, hspace=.7)
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7,5))

ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# %%
import matplotlib.pyplot as plt

fig, f1_axes =plt.subplots(ncols=2, nrows=2, constrained_layout=True)

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

fig2 = plt.figure(constrained_layout=True)
spec2 = gridspec.GridSpec(ncols=2, nrows=2, figure=fig2)

f2_ax1 = fig2.add_subplot(spec2[0,0])
f2_ax2 = fig2.add_subplot(spec2[0,1])
f2_ax3 = fig2.add_subplot(spec2[1,0])
f2_ax4 = fig2.add_subplot(spec2[1,1])

# %%
fig3 = plt.figure(constrained_layout=True)
gs = fig3.add_gridspec(3,3)

# %%
f3_ax1 = fig3.add_subplot(gs[0, :])

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

fig3 = plt.figure(constrained_layout=True)
gs = fig3.add_gridspec(3,3)

f3_ax1 = fig3.add_subplot(gs[0, :])
f3_ax1.set_title('gs[0, :]')

f3_ax1 = fig3.add_subplot(gs[1, :-1])
f3_ax1.set_title('gs[1, :-1]')
f3_ax1 = fig3.add_subplot(gs[1:, -1])
f3_ax1.set_title('gs[1:, -1]')
f3_ax1 = fig3.add_subplot(gs[-1, 0])
f3_ax1.set_title('gs[-1, 0]')
f3_ax1 = fig3.add_subplot(gs[-1, -2])
f3_ax1.set_title('gs[-1, -2]')
# Out:
# Text(0.5, 1.0, 'gs[-1, -2]')

# %%
from matplotlib.gridspec import GridSpec

# %%
gs = GridSpec(8,39)
ax1 = plt.subplot(gs[:6, :35])
ax2 = plt.subplot(gs[6:,:])

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

gs = GridSpec(8,39)
ax1 = plt.subplot(gs[:6, :35])
ax2 = plt.subplot(gs[6:,:])
data1 = np.random.rand(6,35)
data2 = np.random.rand(2,39)

ax1.imshow(data1)
ax2.imshow(data2)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

fig4 = plt.figure(constrained_layout=True)
spec4 =fig4.add_gridspec(ncols=2, nrows=2)

anno_opts = dict(xy=(0.5,0.5), xycoords='axes fraction', va='center', ha='center')

f4_ax1 = fig4.add_subplot(spec4[0,0])
f4_ax1.annotate('Gridspec[0,0]', **anno_opts)

fig4.add_subplot(spec4[0,1]).annotate('GridSpec[0,1:]', **anno_opts)
fig4.add_subplot(spec4[1,0]).annotate('GridSpec[1:,0]', **anno_opts)
fig4.add_subplot(spec4[1,1]).annotate('GridSpec[1:,1:]', **anno_opts)
# Out:
# Text(0.5, 0.5, 'GridSpec[1:,1:]')

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

fig5 = plt.figure(constrained_layout=True)
widths=[2,3,1.5]
heights= [1,3,2]

spec5=fig5.add_gridspec(ncols=3, nrows=3,width_ratios=widths,height_ratios=heights)
for row in range(3):
    for col in range(3):
        ax = fig5.add_subplot(spec5[row, col])
        label = 'width: {}\nnHeight: {}'.format(widths[col], heights[row])
        ax.annotate(label, (0.1,0.5), xycoords='axes fraction', va='center')

# %%
width =[4,6,3]
heights = [1,3,2]
gs_kw=dict(width_ratios=widths, height_ratios=heights)

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
widths=[4,6,3]
heights=[1,3,2]
gs_kw = dict(width_ratios=widths, height_ratios=heights)

fig6, f6_axes=plt.subplots(ncols=3, nrows=3,constrained_layout=True, gridspec_kw=gs_kw)

for r, row in enumerate(f6_axes):
    for c, ax in enumerate(row):
        label='Width: {}\nnHeight: {}'.format(widths[c], heights[r])
        ax.annotate(label, (0.1,0.5), xycoords='axes fraction', va='center')

# %%
fig7, f7_axs =plt.subplots(ncols=3, nrows=3)

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

fig7, f7_axs = plt.subplots(ncols=3, nrows=3)
gs = f7_axs[1,2].get_gridspec()
print(gs)
GridSpec(3,3)
gs =f7_axs[0,2].get_gridspec()
print(gs)
GridSpec(3,3)
# Out:
# GridSpec(3, 3)
# GridSpec(3, 3)
# GridSpec(3, 3)

# %%
f7_axs[1,-1].remove()
f7_axs[2,-1].remove()

# %%
axbig = fig7.add_subplot(gs[1:,-1])

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

fig7, f7_axs = plt.subplots(ncols=3, nrows=3)
gs = f7_axs[1,2].get_gridspec()

f7_axs[1,-1].remove()
f7_axs[2,-1].remove()
axbig = fig7.add_subplot(gs[1:,-1])
axbig.annotate('Big Axes \mnGridSpec[1: , -1]', (0.1,0.5), xycoords='axes fraction', va='center')
fig7.tight_layout()
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\109-1\AppData\Local\Temp\ipykernel_6468\2865971301.py:10: SyntaxWarning: invalid escape sequence '\m'
#   axbig.annotate('Big Axes \mnGridSpec[1: , -1]', (0.1,0.5), xycoords='axes fraction', va='center')

# %%
import numpy as np
import matplotlib.pyplot as plt

def squiggle_xy(a,b,c,d,i=np.arange(0.0,2*np.pi,0.05)):
    return np.sin(i*a)*np.cos(i*b), np.sin(i*c)*np.cos(i*d)

fig =plt.figure(figsize=(4,4))

plt.plot(*squiggle_xy(1,2,1,3))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

def squiggle_xy(a,b,c,d, i=np.arange(0.0, 2*np.pi,0.05)):
    return np.sin(i*a)*np.cos(i*c)*np.cos(i*d)

fig11 = plt.figure(figsize=(8,8), constrained_layout=Fals)
outer_grid = fig11.add_gridspec(4,4,wspace=0, hspace=0)

for in range(4):
    for in range(4):
        inner_grid = outer_grid[a,b].subgridspec(3,3,wspace=0, hspace=0)
        axs= inner_grid.subplots()
grid.
for(c,d), ax in np.ndenumerate(axs):
    ax.plot(*squiggle_xy(a+1,b+1,c+1,d+1))
    ax.set(xticks=[], yticks=[])
    
    forax in fig11.get_axes():
        ss =ax.get_subplotspec()
        ax.spines.top.set_visible(ss.is_first_row())
         ax.spines.bottom.set_visible(ss.is_last_row())
          ax.spines.left.set_visible(ss.is_first_col())
           ax.spines.right.set_visible(ss.is_last_col())
# Out:
#   Cell In[65], line 11
#     for in range(4):
#         ^
# SyntaxError: invalid syntax
