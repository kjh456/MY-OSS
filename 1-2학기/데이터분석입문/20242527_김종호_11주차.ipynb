# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\109-1\appdata\local\programs\python\python312\lib\site-packages (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install csv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement csv (from versions: none)
# ERROR: No matching distribution found for csv
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\109-1\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\109-1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\109-1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\109-1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\109-1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\109-1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\109-1\appdata\roaming\python\python312\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\109-1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\109-1\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\109-1\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\109-1\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
sys.version
# Out:
# '3.12.4 (tags/v3.12.4:8e8a4ba, Jun  6 2024, 19:30:16) [MSC v.1940 64 bit (AMD64)]'

# %%
import site
site.getsitepackages()
# Out:
# ['c:\\Users\\109-1\\AppData\\Local\\Programs\\Python\\Python312',
#  'c:\\Users\\109-1\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages']

# %%
import matplotlib as mpl
print(mpl.__version__)

import numpy as np
print(np.__version__)
# Out:
# 3.9.2
# 2.1.3

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rc('axes', unicode_minus=False)
plt.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rc('axes', unicode_minus=False)
plt.rcParams['axes.unicode_minus'] = False

# %%
import csv

f = open('age.csv', encoding='cp949')
data = csv.reader(f)
 
for row in data :
    print(row)

f.close()
# Out:
# ['占쏙옙占쏙옙占쏙옙占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_占쏙옙占싸깍옙占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_占쏙옙占심깍옙占쏙옙占싸깍옙占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_0占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_1占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_2占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_3占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_4占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_5占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_6占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_7占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_8占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_9占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_10占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_11占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_12占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_13占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_14占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_15占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_16占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_17占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_18占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_19占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_20占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_21占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_22占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_23占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_24占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_25占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_26占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_27占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_28占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_29占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_30占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_31占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_32占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_33占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_34占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_35占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_36占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_37占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_38占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_39占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_40占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_41占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_42占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_43占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_44占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_45占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_46占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_47占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_48占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_49占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_50占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_51占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_52占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_53占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_54占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_55占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_56占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_57占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_58占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_59占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_60占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_61占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_62占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_63占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_64占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_65占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_66占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_67占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_68占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_69占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_70占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_71占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_72占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_73占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_74占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_75占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_76占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_77占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_78占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_79占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_80占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_81占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_82占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_83占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_84占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_85占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_86占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_87占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_88占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_89占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_90占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_91占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_92占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_93占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_94占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_95占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_96占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_97占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_98占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_99占쏙옙', '2024占쏙옙10占쏙옙_占쏙옙_100占쏙옙 占싱삼옙']
# ['占쏙옙占쏙옙  (0000000000)', '51,238,450', '51,238,450', '229,262', '236,471', '255,815', '270,108', '285,248', '312,958', '338,366', '370,586', '421,425', '444,790', '442,008', '449,304', '488,716', '482,058', '465,675', '450,445', '475,303', '488,210', '445,304', '438,372', '478,137', '487,084', '502,648', '574,718', '634,269', '617,108', '644,044', '669,545', '690,834', '700,225', '710,414', '714,007', '722,009', '679,045', '646,382', '628,616', '615,629', '619,722', '631,548', '645,262', '677,639', '753,551', '822,374', '824,205', '846,884', '801,997', '735,987', '761,733', '744,668', '788,491', '864,673', '871,877', '872,750', '931,391', '898,294', '910,890', '906,487', '828,123', '807,316', '826,728', '764,425', '813,316', '827,488', '907,658', '891,683', '793,428', '733,553', '723,713', '654,557', '673,718', '556,216', '489,624', '531,012', '383,772', '410,531', '412,881', '397,236', '391,642', '289,704', '280,425', '282,414', '283,089', '320,595', '245,077', '213,704', '203,107', '171,886', '147,844', '125,469', '108,723', '84,326', '64,428', '51,608', '35,552', '29,138', '21,882', '15,560', '10,656', '6,154', '4,284', '8,644']
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[10], line 6
#       3 f = open('age.csv', encoding='cp949')
#       4 data = csv.reader(f)
# ----> 6 for row in data :
#       7     print(row)
#       9 f.close()
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xbd in position 2466: illegal multibyte sequence

# %%
print('신도림' in '서울특별시 구로구 신도림동(1153051000)')
print('1153' in '서울특별시 구로구 신도림동(1153051000)')
print('()' in '서울특별시 구로구 신도림동(1153051000)')
# Out:
# True
# True
# False

# %%
print('신도림' in '서울특별시 구로구 신도림동(1153051000)')
print('1153' in '서울특별시 구로구 신도림동(1153051000)')
print('()' in '서울특별시 구로구 신도림동(1153051000)')
# Out:
# True
# True
# False

# %%
import csv

f = open('age.csv', encoding='cp949')
data = csv.reader(f)

for row in data :
    if '신도림' in row[0] :
        print(row)

f.close()

# %%
import csv

f = open('age.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)
print(header)

f.close()

# %%
import csv

f = open('age.csv', encoding='cp949')
data = csv.reader(f)

result = []
for row in data :
    if '신도림' in row[0] :
        for i in row[3:] :
            result.append(int(i))

f.close()
print(result)

# %%
import csv
import matplotlib.pyplot as plt

f = open('age.csv', encoding='cp949')
data = csv.reader(f)

result = []
for row in data :
    if '신도림' in row[0]:
        for i in row[3:]:
            result.append(int(i))

f.close()

# plt.style.use('ggplot')
plt.plot(result)
plt.xlabel('Age')
plt.ylabel('Population')
plt.grid(True)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('age.csv', encoding='cp949')
data = csv.reader(f)

result = []
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
for row in data :
    if name in row[0] :
        for i in row[3:] :
            result.append(int(i))

f.close()

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

plt.plot(result)
plt.title(f'{name} 지역의 연령에 따른 인구수')
plt.xlabel('Age')
plt.ylabel('Population')
plt.grid(True)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('age.csv', encoding='cp949')
data = csv.reader(f)

result = []
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
for row in data :
    if name in row[0] :
        for i in row[3:] :
            result.append(int(i))

f.close()

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

plt.plot(result)
plt.title(f'{name} 지역의 연령에 따른 인구수')
plt.xlabel('Age')
plt.ylabel('Population')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.bar([0,1,2,4,6,10], [1,2,3,5,6,7])
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('age.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)

result = []
for row in data :
    if '신도림' in row[0] :
        for i in row[3:] :
            result.append(int(i))

f.close()

plt.figure(figsize=(10, 2))
plt.bar(range(len(result)), result)

plt.xlabel('Age')
plt.ylabel('Population')
plt.grid(True)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('age.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)

result = []
for row in data :
    if '신도림' in row[0] :
        for i in row[3:] :
            result.append(int(i))

f.close()

plt.figure(figsize=(5, 10))
plt.barh(range(len(result)), result)

plt.xlabel('Population')
plt.ylabel('Age')
plt.grid(True)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)

male = []
female = []

for row in data :
    if '신도림' in row[0] :
        for i in row[3:104] :
            male.append(int(i))
        for i in row[106:] :
            female.append(int(i))

f.close()

plt.barh(range(len(male)), male, color='b', label='male')
plt.barh(range(len(female)), female, color='r', label='female')

plt.xlabel('Population')
plt.ylabel('Age')
plt.grid(True)
plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)
male = []
female = []

for row in data :
    if '신도림' in row[0] :
        for i in row[3:104] :
            male.append(-int(i))
        for i in row[106:] :
            female.append(int(i))

f.close()

plt.barh(range(len(male)), male, color='b', label='male')
plt.barh(range(len(female)), female, color='r', label='female')

plt.xlabel('Population')
plt.ylabel('Age')
plt.grid(True)
plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)
male = []
female = []

name = input('찾고 싶은 지역의 이름을 알려주세요: ')
area = ''

for row in data :
    if name in row[0] :
        area = row[0]
        for i in row[3:104] :
            male.append(-int(i))
        for i in row[106:] :
            female.append(int(i))

f.close()
plt.rc('font', family = 'Malgun Gothic')
plt.rc('axes', unicode_minus = False)

plt.barh(range(len(male)), male, color='b', label='male')
plt.barh(range(len(female)), female, color='r', label='female')
plt.title(f'{area} 지역의 남녀 성별 인구 분포')
plt.xlabel('Population')
plt.ylabel('Age')
plt.grid(True)
plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)

male = []
female = []

name = input('찾고 싶은 지역의 이름을 알려주세요: ') 
# 제주특별자치도

for row in data :
    if name in row[0] :
        for i in row[3:104] :
            i = i.replace(',', '')
            male.append(-int(i))
        for i in row[106:] :
            i = i.replace(',', '')
            female.append(int(i))

f.close()
plt.rc('font', family = 'Malgun Gothic')
plt.rc('axes', unicode_minus = False)

plt.barh(range(len(male)), male, color='b', label='male')
plt.barh(range(len(female)), female, color='r', label='female')

plt.title(f'{name} 지역의 남녀 성별 인구 분포')
plt.xlabel('Population')
plt.ylabel('Age')
plt.grid(True)
plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)
male = []
female = []

name = input('찾고 싶은 지역의 이름을 알려주세요: ')
# 제주특별자치도

for row in data :
    if name in row[0] :
        for i in row[3:104] :
            i = i.replace(',', '')
            male.append(-int(i))
        for i in row[106:] :
            i = i.replace(',', '')
            female.append(int(i))
        break # 가장 위 하나만 처리

f.close()
plt.rc('font', family = 'Malgun Gothic')
plt.rc('axes', unicode_minus = False)

plt.barh(range(len(male)), male, color='b', label='male')
plt.barh(range(len(female)), female, color='r', label='female')
plt.title(f'{name} 지역의 남녀 성별 인구 분포')

plt.xlabel('Population')
plt.ylabel('Age')
plt.grid(True)
plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)

name = input('궁금한 지역의 이름을 입력하세요: ')
# 제주

for row in data :
    if name in row[0] :
        male = 0
        female = 0
        for i in row[3:104] :
            i = i.replace(',', '')
            male = male + int(i)
        for i in row[106:] :
            i = i.replace(',', '')
            female = female + int(i)
        break

f.close()

print(f'남성 인구 합: {male} 명')
print(f'여성 인구 합: {female} 명')

# %%
import csv
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)

name = input('궁금한 지역의 이름을 입력하세요: ')
# 제주

for row in data :
    if name in row[0] :
        male = 0
        female = 0
        for i in row[3:104] :
            i = i.replace(',', '')
            male = male + int(i)
        for i in row[106:] :
            i = i.replace(',', '')
            female = female + int(i)
        break

f.close()

plt.rc('font', family ='Malgun Gothic')
labels = ['male','female']
colors = ['skyblue', 'pink']

plt.pie([male, female], labels=labels, autopct ='%.1f%%', colors=colors)
plt.title(name + ' 지역의 남녀 성별 비율')
plt.axis('equal')
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)

name = input('궁금한 지역의 이름을 입력하세요: ')
# 제주특별자치도

for row in data :
    if name in row[0] :
        male = 0
        female = 0
        for i in row[3:104] :
            i = i.replace(',', '')
            male = male + int(i)
        for i in row[106:] :
            i = i.replace(',', '')
            female = female + int(i)
        break

f.close()

plt.rc('font', family ='Malgun Gothic')
labels = ['male','female']
colors = ['skyblue', 'pink']

plt.pie([male, female], labels=labels, autopct ='%.1f%%', colors=colors, startangle =90)
plt.title(name + ' 지역의 남녀 성별 비율')
plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter([1,2,3,4], [10,30,20,40])
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter([1,2,3,4], [10,30,20,40], s=[100,200,250,300])
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter([1,2,3,4], [10,30,20,40], s = [30,60,90,120], c = ['red','blue','green','gold'])
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter([1,2,3,4], [10,30,20,40],
            s = [30,60,90,120],
            c = ['red','blue','green','gold'], 
            marker='p')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter([1, 2, 3, 4], [10, 30, 20, 40], s=[30, 60, 90, 120], c=range(4))
plt.colorbar()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.scatter([1,2,3,4], [10,30,20,40], s = [30,60,90,120], c=range(4), cmap='jet')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('default')
plt.scatter([1,2,3,4], [10,30,20,40], s = [30,60,90,120], c=range(4), cmap='GnBu')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8')
plt.scatter([1,2,3,4], [10,30,20,40], s = [30,60,90,120], c=range(4), cmap='GnBu')
plt.colorbar()
plt.show()

# %%
from matplotlib import colormaps
list(colormaps)
# Out:
# ['magma',
#  'inferno',
#  'plasma',
#  'viridis',
#  'cividis',
#  'twilight',
#  'twilight_shifted',
#  'turbo',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
#  'Set1',
#  'Set2',
#  'Set3',
#  'tab10',
#  'tab20',
#  'tab20b',
#  'tab20c',
#  'grey',
#  'gist_grey',
#  'gist_yerg',
#  'Grays',
#  'magma_r',
#  'inferno_r',
#  'plasma_r',
#  'viridis_r',
#  'cividis_r',
#  'twilight_r',
#  'twilight_shifted_r',
#  'turbo_r',
#  'Blues_r',
#  'BrBG_r',
#  'BuGn_r',
#  'BuPu_r',
#  'CMRmap_r',
#  'GnBu_r',
#  'Greens_r',
#  'Greys_r',
#  'OrRd_r',
#  'Oranges_r',
#  'PRGn_r',
#  'PiYG_r',
#  'PuBu_r',
#  'PuBuGn_r',
#  'PuOr_r',
#  'PuRd_r',
#  'Purples_r',
#  'RdBu_r',
#  'RdGy_r',
#  'RdPu_r',
#  'RdYlBu_r',
#  'RdYlGn_r',
#  'Reds_r',
#  'Spectral_r',
#  'Wistia_r',
#  'YlGn_r',
#  'YlGnBu_r',
#  'YlOrBr_r',
#  'YlOrRd_r',
#  'afmhot_r',
#  'autumn_r',
#  'binary_r',
#  'bone_r',
#  'brg_r',
#  'bwr_r',
#  'cool_r',
#  'coolwarm_r',
#  'copper_r',
#  'cubehelix_r',
#  'flag_r',
#  'gist_earth_r',
#  'gist_gray_r',
#  'gist_heat_r',
#  'gist_ncar_r',
#  'gist_rainbow_r',
#  'gist_stern_r',
#  'gist_yarg_r',
#  'gnuplot_r',
#  'gnuplot2_r',
#  'gray_r',
#  'hot_r',
#  'hsv_r',
#  'jet_r',
#  'nipy_spectral_r',
#  'ocean_r',
#  'pink_r',
#  'prism_r',
#  'rainbow_r',
#  'seismic_r',
#  'spring_r',
#  'summer_r',
#  'terrain_r',
#  'winter_r',
#  'Accent_r',
#  'Dark2_r',
#  'Paired_r',
#  'Pastel1_r',
#  'Pastel2_r',
#  'Set1_r',
#  'Set2_r',
#  'Set3_r',
#  'tab10_r',
#  'tab20_r',
#  'tab20b_r',
#  'tab20c_r']

# %%
import matplotlib.pyplot as plt

plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
import random
import matplotlib.pyplot as plt

x = []
y = []
size = []

for i in range(100) : 
    x.append(random.randint(50,100))
    y.append(random.randint(50,100))
    size.append(random.randint(10,100))

plt.style.use('default')   
plt.scatter(x, y, s=size)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import random

x = []
y = []
size = []

for i in range(100) : 
    x.append(random.randint(50,100))
    y.append(random.randint(50,100))
    size.append(random.randint(10,100))
    
plt.scatter(x, y, s=size, c=size, cmap='jet')
plt.colorbar()
plt.grid(True)
plt.show()

# %%
import random
import matplotlib.pyplot as plt

x = []
y = []
size = []

for i in range(100) : 
    x.append(random.randint(50,100))
    y.append(random.randint(50,100))
    size.append(random.randint(10,100))
    
plt.scatter(x, y, s=size, c=y, cmap='jet')
plt.colorbar()
plt.grid(True)
plt.show()

# %%
import random
import matplotlib.pyplot as plt

x = []
y = []
size = []

for i in range(100) : 
    x.append(random.randint(50,100))
    y.append(random.randint(50,100))
    size.append(random.randint(10,100))
    
plt.scatter(x, y, s = size, c=size, cmap='jet', alpha=.9)
plt.colorbar()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('default')

# make the data
# np.random.seed(3)
x = 4 + np.random.normal(0, 2, 24) # 평균 0, 표준편차 2, 난수 24개 생성
y = 4 + np.random.normal(0, 2, len(x))
# size and color:
sizes = np.random.uniform(15, 80, len(x)) # [15, 80) 사이의 난수 24개 생성]
colors = np.random.uniform(15, 80, len(x))

# plot
fig, ax = plt.subplots()
ax.scatter(x, y, s=sizes, c=colors)
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
for color in ['tab:blue', 'tab:orange', 'tab:green']:
    n=75
    x,y=np.random.rand(2,n)
    scale = 300.0 *np.random.rand(n)
    ax.scatter(x,y,c=color,s=scale,label=color,alpha=0.3,edgecolors='red')
    
ax.legend()
ax.grid(True)
plt.show()

# %%
# from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

n = 100
xmin, xmax, ymin, ymax, zmin, zmax = 0, 20, 0, 30, 0, 50
cmin, cmax = 0, 2

# (b - a) * random_sample() + a : [a, b),  b > a` random number
xs = np.array([(xmax - xmin) * np.random.random_sample() + xmin for i in range(n)])
ys = np.array([(ymax - ymin) * np.random.random_sample() + ymin for i in range(n)])
zs = np.array([(zmax - zmin) * np.random.random_sample() + zmin for i in range(n)])
color = np.array([(cmax - cmin) * np.random.random_sample() + cmin for i in range(n)])

fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs, ys, zs, c=color, marker='o', s=15, cmap='Greens')

plt.show()
